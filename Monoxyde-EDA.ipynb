# %%
import pandas as pd
import matplotlib.pyplot as pltimpo
import os

# %%
path = "./dataset_CO_RH"
files = os.listdir(path)[:-1]

# %%
ptf = path + "/" + files[1]
df = pd.read_csv(ptf)
df
# Out:
#          Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# 0           0.309       0.0             50.25            26.54
# 1           0.619       0.0             50.25            26.54
# 2           0.928       0.0             50.25            26.54
# 3           1.235       0.0             50.25            26.54
# 4           1.545       0.0             50.25            26.54
# ...           ...       ...               ...              ...
# 295510  90908.366       0.0             62.28            26.42
# 295511  90908.671       0.0             62.28            26.42
# 295512  90908.976       0.0             62.28            26.42
# 295513  90909.281       0.0             62.28            26.42
# 295514  90909.585       0.0             62.28            26.42
#
#         Flow rate (mL/min)  Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  \
# 0                 242.0039              0.8928     0.0710     0.1436
# ...

# %% [markdown]
# ### Cleaning Data
# The last 20 columns represent empty data

# %%
df = df.iloc[:,:-20]
df

# %%
df.describe()
# Out:
#             Time (s)       CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# count  295515.000000  295515.000000     295515.000000    295515.000000
# mean    45451.065113       9.899970         45.748160        26.427411
# std     26235.249366       6.429014         12.467859         0.103742
# min         0.309000       0.000000         16.390000        26.140000
# 25%     22738.269500       4.440000         36.140000        26.380000
# 50%     45451.505000       8.890000         46.650000        26.460000
# 75%     68153.354500      15.560000         55.330000        26.500000
# max     90909.585000      20.000000         72.920000        26.620000
#
#        Flow rate (mL/min)  Heater voltage (V)      R1 (MOhm)      R2 (MOhm)  \
# count       295515.000000       295515.000000  295515.000000  295515.000000
# mean           239.942507            0.355318      15.331624      17.590599
# std              1.935526            0.288692      22.708008      26.811309
# ...

# %% [markdown]
# ## Data Visualization
